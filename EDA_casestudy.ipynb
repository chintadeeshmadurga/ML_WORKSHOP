# %%
import numpy as np 
import pandas as pd

# %%
data = pd.read_csv('titanic.csv')
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
 data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    str
#  4   Sex          891 non-null    str
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    str
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    str
#  11  Embarked     889 non-null    str
# dtypes: float64(2), int64(5), str(5)
# memory usage: 118.9 KB

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='str')

# %%
data.dtypes;
data.select_dtypes(include='object')
data.select_dtypes(include=('int','float'))
# Out:
# C:\Users\chint\AppData\Local\Temp\ipykernel_5572\2609100832.py:2: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   data.select_dtypes(include='object')
#      PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare
# 0              1         0       3  22.0      1      0   7.2500
# 1              2         1       1  38.0      1      0  71.2833
# 2              3         1       3  26.0      0      0   7.9250
# 3              4         1       1  35.0      1      0  53.1000
# 4              5         0       3  35.0      0      0   8.0500
# ...

# %%
print('Total number of passengers in ship are',len(data))
# Out:
# Total number of passengers in ship are 891

# %%
data.describe(include='object')
# Out:
# C:\Users\chint\AppData\Local\Temp\ipykernel_5572\3382516499.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   data.describe(include='object')
#                            Name   Sex  Ticket Cabin Embarked
# count                       891   891     891   204      889
# unique                      891     2     681   147        3
# top     Braund, Mr. Owen Harris  male  347082    G6        S
# freq                          1   577       7     4      644

# %%
data['Cabin'].unique()
# Out:
# <ArrowStringArray>
# [          nan,         'C85',        'C123',         'E46',          'G6',
#         'C103',         'D56',          'A6', 'C23 C25 C27',         'B78',
#  ...
#         'B102',         'B69',         'E49',         'C47',         'D28',
#          'E17',         'A24',         'C50',         'B42',        'C148']
# Length: 148, dtype: str

# %%
data['Sex'].unique()
# Out:
# <ArrowStringArray>
# ['male', 'female']
# Length: 2, dtype: str

# %%
data['Sex'].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
data['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
data['Pclass'].value_counts()
data['Pclass'].value_counts(ascending=True)
# Out:
# Pclass
# 2    184
# 1    216
# 3    491
# Name: count, dtype: int64

# %%
data['Age'].value_counts()
# Out:
# Age
# 24.00    30
# 22.00    27
# 18.00    26
# 28.00    25
# 19.00    25
#          ..
# 24.50     1
# 0.67      1
# 0.42      1
# 34.50     1
# 74.00     1
# Name: count, Length: 88, dtype: int64

# %%
data['Fare']
# Out:
# 0       7.2500
# 1      71.2833
# 2       7.9250
# 3      53.1000
# 4       8.0500
#         ...
# 886    13.0000
# 887    30.0000
# 888    23.4500
# 889    30.0000
# 890     7.7500
# Name: Fare, Length: 891, dtype: float64

# %%
data['Age'].value_counts().head(30)
# Out:
# Age
# 24.0    30
# 22.0    27
# 18.0    26
# 28.0    25
# 19.0    25
# 30.0    25
# 21.0    24
# 25.0    23
# 36.0    22
# 29.0    20
# 26.0    18
# 35.0    18
# 27.0    18
# 32.0    18
# 31.0    17
# 16.0    17
# 20.0    15
# 34.0    15
# 33.0    15
# 23.0    15
# 39.0    14
# 40.0    13
# 42.0    13
# 17.0    13
# 45.0    12
# 38.0    11
# 2.0     10
# 4.0     10
# 50.0    10
# 47.0     9
# Name: count, dtype: int64

# %%
data.sample(10)
# Out:
#      PassengerId  Survived  Pclass  \
# 39            40         1       3
# 118          119         0       1
# 487          488         0       1
# 268          269         1       1
# 259          260         1       2
# 144          145         0       2
# 389          390         1       2
# 127          128         1       3
# 427          428         1       2
# 141          142         1       3
#
#                                                   Name     Sex   Age  SibSp  \
# 39                         Nicola-Yarred, Miss. Jamila  female  14.0      1
# 118                           Baxter, Mr. Quigg Edmond    male  24.0      0
# 487                            Kent, Mr. Edward Austin    male  58.0      0
# 268      Graham, Mrs. William Thompson (Edith Junkins)  female  58.0      0
# 259                        Parrish, Mrs. (Lutie Davis)  female  50.0      0
# 144                         Andrew, Mr. Edgardo Samuel    male  18.0      0
# ...

# %%
import matplotlib.pyplot as plt

# %%
counts,edges,bars=plt.hist(data['Age'],bins=15,color='lightblue')
print(counts)
print(bars)
plt.xlabel("Age")
plt.ylabel("count")
plt.bar_label(bars)
plt.title("Age Distribution")
plt.show()
# Out:
# [ 44.  24.  32. 104. 115. 127.  80.  59.  49.  30.  22.  17.   4.   6.
#    1.]
# <BarContainer object of 15 artists>

# %%
data['Pclass'].value_counts().plot(kind='barh',color='pink')
# Out:
# <Axes: ylabel='Pclass'>

# %%
data['Pclass'].value_counts().plot(kind='bar',color='navajowhite')
# Out:
# <Axes: xlabel='Pclass'>

# %%
plt.bar(data['Survived'],data['Sex'],color='lightcyan')
plt.xlabel("survived Rate")
plt.ylabel("gender")
plt.title("GENDER SURVIVED DISTRIBUTION",color='lightcoral')
plt.show()

# %%
data['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
index=data['Survived'].value_counts().keys().tolist()
print(index)
labels=data['Survived'].value_counts().values.tolist()
print(labels)
# Out:
# [0, 1]
# [549, 342]

# %%
plt.pie(x=labels,labels=['Dead','Alive'],colors=['tan','beige'],autopct="%.1f%%")
plt.title("SURVIVED DISTIBUTION",color='brown')
plt.legend()
plt.show()

# %%
plt.pie(x=[577,314],labels=['MALE','FEMALE'],colors=['cornflowerblue','hotpink'],autopct="%.1f%%")
plt.title("GENDER DISTIBUTION",color='gray')
plt.legend()
plt.show()

# %%
plt.scatter(x=data['Age'],y=data['Fare'],color='silver')
plt.xlabel("Age")
plt.ylabel("Fare")
plt.title("Age vs Fare Distriubution")
plt.show()

# %%
import plotly

# %%
import cufflinks

# %%
# !pip install cufflinks
# Out:
# ...
# [notice] A new release of pip available: 22.3.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import plotly as py
import plotly.graph_objects as go

# %%
trace = go.Histogram(x=data['Age'],nbinsx=20,marker={'color':'lightpink'})
layout=go.Layout(title="Age Distribution")
fig=go.Figure(data=trace,layout=layout)
fig

# %%
print(index)
print(labels)
# Out:
# [0, 1]
# [549, 342]

# %%
trace=go.Pie(labels=['Dead','Alive'],values=[549,371])
layout=go.Layout(title='Survived Distribution')
fig=go.Figure(data=trace,layout=layout)
fig.show()

# %%
trace=go.Box(x=data['Pclass'],y=data['Age'],marker={'color':'slateblue'})
layout=go.Layout(title="Age vs Pclass Distribution")
fig=go.Figure(data=trace,layout=layout)
fig.show()

# %%
trace = go.Scatter(x=data['Age'],y=data['Fare'],mode='markers',marker={'color':'gold'})
layout=go.Layout(title='Age VS Fare Distribution')
fig = go.Figure(data=trace, layout=layout)
fig.show()

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
print(data['Age'].mean())
# Out:
# 29.69911764705882

# %%
data['Age']
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
data['Age'] =data['Age'].fillna(data['Age'].mean())
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
pclass = pd.get_dummies(data['Pclass'],drop_first=True,dtype=int)
pclass
# Out:
#      2  3
# 0    0  1
# 1    0  0
# 2    0  1
# 3    0  0
# 4    0  1
# ..  .. ..
# 886  1  0
# 887  0  0
# 888  0  1
# 889  0  0
# 890  0  1
#
# [891 rows x 2 columns]

# %%
gender = pd.get_dummies(data['Sex'],drop_first=True,dtype=int)
gender
# Out:
#      male
# 0       1
# 1       0
# 2       0
# 3       0
# 4       1
# ..    ...
# 886     1
# 887     0
# 888     0
# 889     1
# 890     1
#
# [891 rows x 1 columns]

# %%
Embarked= pd.get_dummies(data['Embarked'],dtype=int)
Embarked
# Out:
#      C  Q  S
# 0    0  0  1
# 1    1  0  0
# 2    0  0  1
# 3    0  0  1
# 4    0  0  1
# ..  .. .. ..
# 886  0  0  1
# 887  0  0  1
# 888  0  0  1
# 889  1  0  0
# 890  0  1  0
#
# [891 rows x 3 columns]

# %%
final_data = pd.concat([data,pclass,gender,Embarked],axis=1)
final_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
final_data.columns
# Out:
# Index(['PassengerId',    'Survived',      'Pclass',        'Name',
#                'Sex',         'Age',       'SibSp',       'Parch',
#             'Ticket',        'Fare',       'Cabin',    'Embarked',
#                    2,             3,        'male',           'C',
#                  'Q',           'S'],
#       dtype='object')

# %%
final_data.drop(columns=['PassengerId','Name','Pclass','Sex','Ticket','Embarked'],inplace=True)
final_data.head()
# Out:
#    Survived   Age  SibSp  Parch     Fare Cabin  2  3  male  C  Q  S
# 0         0  22.0      1      0   7.2500   NaN  0  1     1  0  0  1
# 1         1  38.0      1      0  71.2833   C85  0  0     0  1  0  0
# 2         1  26.0      0      0   7.9250   NaN  0  1     0  0  0  1
# 3         1  35.0      1      0  53.1000  C123  0  0     0  0  0  1
# 4         0  35.0      0      0   8.0500   NaN  0  1     1  0  0  1
